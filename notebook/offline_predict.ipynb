# %%
from util import *
import matplotlib.pyplot as plt
import seaborn as ses

# %%
test = load_testA()

# %%
mallids = test.mall_id.unique()
for mallid in mallids:
    if test[test.mall_id == mallid].shape[0] > 10000:
        print mallid, test[test.mall_id == mallid].shape[0]
# Out:
# m_7168 11737
# m_1175 13901
# m_3005 10277
# m_690 11808

# %%
mall_id = "m_7168"
index = 0
train = load_train()
train = train[train.mall_id == mall_id]
train.time_stamp = pd.to_datetime(train.time_stamp)
predict = pd.read_csv("../result/offline_predict/{}_{}.csv".format(mall_id,index))
_train_index,_valid_index=get_last_one_week_index(train)
_valid = train.iloc[_valid_index]
_train = train.iloc[_train_index]
error = _valid.loc[_valid.index[predict.predict != predict.real]]
correct = _valid.loc[_valid.index[predict.predict == predict.real]]
# Out:
# /usr/lib64/python2.7/site-packages/pandas/core/generic.py:2773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
df, (train_index, train_use_wifi, train_matrix), (test_index, test_use_wifi, test_matrix) = get_wifi_cache(mall_id)

# %%
f,ax = plt.subplots(1,1,figsize=(20,50))
ses.countplot(y="shop_id", data=error,ax=ax)
plt.show()

# %%
ses.countplot(x = error.time_stamp.dt.hour)
plt.show()

# %%
ses.countplot(x = correct.time_stamp.dt.hour)
plt.show()

# %%
ses.countplot(train.time_stamp.dt.hour)
plt.show()

# %%
shopids = train.shop_id.unique()

# %%
for _sid in shopids:
    print _sid
    _p = train[train.shop_id == _sid]
    ses.countplot(_p.time_stamp.dt.hour)
    plt.show()
# Out:
# s_301215
# s_190419
# s_165228
# s_256254
# s_2527
# s_3587253
# s_456529
# s_2999731
# s_385716
# s_293805
# s_2956027
# s_293082
# s_736490
# s_295706
# s_46295
# s_864378
# s_938918
# s_524841
# s_2303143
# s_381583
# s_77146
# s_381725
# s_293785
# s_39875
# s_43369
# s_179310
# s_97734
# s_293704
# s_3032986
# s_533833
# s_45040
# s_2303129
# s_788134
# s_295308
# s_4386
# s_294960
# s_294294
# s_2783591
# s_2310712
# s_3741710
# s_41948
# s_62317
# s_60293
# s_7452
# s_2951768
# s_135671
# s_1224414
# s_3882870
# s_3966496
# s_50078
# s_20731
# s_59928
# s_297009
# s_555648
# s_295192
# s_2959694
# s_293031
# s_294228
# s_71210
# s_460419
# s_8426
# s_136016
# s_3568936
# s_60681
# s_295610
# s_3846218
# s_306243
# s_3886681
# s_2195618
# s_376242
# s_3749811
# s_1139383
# s_381787
# s_2953551
# s_747466
# s_15236
# s_63306
# s_448230
# s_474939
# s_390156
# s_5014
# s_3033946
# s_293610
# s_3009393
# s_454017
# s_42761
# s_3994800
# s_4371
# s_54082
# s_182683
# s_383953
# ...
